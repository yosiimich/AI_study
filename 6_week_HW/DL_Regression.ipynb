# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
from io import StringIO

file_path = './diabetes.csv'

df = pd.read_csv(file_path)
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df = df.drop('Outcome',axis=1)
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# 2                       0.672   32
# 3                       0.167   21
# 4                       2.288   33
# ..                        ...  ...
# 763                     0.171   63
# 764                     0.340   27
# 765                     0.245   30
# 766                     0.349   47
# 767                     0.315   23
#
# [768 rows x 8 columns]

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# dtype: int64

# %%
df = df.dropna()
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# dtype: int64

# %%
X = df.drop('BMI',axis=1)
X
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# 0              6      148             72             35        0
# 1              1       85             66             29        0
# 2              8      183             64              0        0
# 3              1       89             66             23       94
# 4              0      137             40             35      168
# ..           ...      ...            ...            ...      ...
# 763           10      101             76             48      180
# 764            2      122             70             27        0
# 765            5      121             72             23      112
# 766            1      126             60              0        0
# 767            1       93             70             31        0
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# 2                       0.672   32
# 3                       0.167   21
# 4                       2.288   33
# ..                        ...  ...
# 763                     0.171   63
# 764                     0.340   27
# 765                     0.245   30
# 766                     0.349   47
# 767                     0.315   23
#
# [768 rows x 7 columns]

# %%
Y = df['BMI']
Y.value_counts()
# Out:
# BMI
# 32.0    13
# 31.6    12
# 31.2    12
# 0.0     11
# 32.4    10
#         ..
# 36.7     1
# 41.8     1
# 42.6     1
# 42.8     1
# 46.3     1
# Name: count, Length: 248, dtype: int64

# %% [markdown]
# ## 넘파이 전처리

# %%
X = X.values
Y = Y.values

# %% [markdown]
# ## 딥러닝 시작

# %%
from sklearn.model_selection import train_test_split
X_train,X_test, y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state=0) 
X_train.shape, y_train.shape, X_test.shape, y_test.shape,
# Out:
# ((614, 7), (614,), (154, 7), (154,))

# %%
#Defining the model 

from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD,Adam


model = Sequential()

model.add(Dense(10,input_shape=(7,),activation='tanh'))
model.add(Dense(10,activation='tanh'))
model.add(Dense(10,activation='tanh'))
model.add(Dense(1))

model.compile(optimizer = 'rmsprop', loss = 'mse', metrics = ['mse'])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 10)                80
#
#  dense_5 (Dense)             (None, 10)                110
#
#  dense_6 (Dense)             (None, 10)                110
#
#  dense_7 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 311 (1.21 KB)
# Trainable params: 311 (1.21 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
N_EPOCHS = 40

history=model.fit(x=X_train, y=y_train, epochs=N_EPOCHS, batch_size=32,validation_data= (X_test,y_test))
y_pred = model.predict(X_test)
# Out:
# Epoch 1/40
# WARNING:tensorflow:From C:\Users\yosim\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\yosim\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 20/20 [==============================] - 2s 20ms/step - loss: 1053.4746 - mse: 1053.4746 - val_loss: 958.4626 - val_mse: 958.4626
# Epoch 2/40
# 20/20 [==============================] - 0s 6ms/step - loss: 996.5046 - mse: 996.5046 - val_loss: 913.9418 - val_mse: 913.9418
# Epoch 3/40
# 20/20 [==============================] - 0s 5ms/step - loss: 950.4076 - mse: 950.4076 - val_loss: 867.6335 - val_mse: 867.6335
# Epoch 4/40
# 20/20 [==============================] - 0s 6ms/step - loss: 908.5366 - mse: 908.5366 - val_loss: 827.7345 - val_mse: 827.7345
# Epoch 5/40
# 20/20 [==============================] - 0s 5ms/step - loss: 868.7939 - mse: 868.7939 - val_loss: 790.9059 - val_mse: 790.9059
# Epoch 6/40
# 20/20 [==============================] - 0s 6ms/step - loss: 833.1215 - mse: 833.1215 - val_loss: 758.6824 - val_mse: 758.6824
# Epoch 7/40
# 20/20 [==============================] - 0s 5ms/step - loss: 803.4456 - mse: 803.4456 - val_loss: 730.6696 - val_mse: 730.6696
# Epoch 8/40
# 20/20 [==============================] - 0s 5ms/step - loss: 778.8027 - mse: 778.8027 - val_loss: 709.5891 - val_mse: 709.5891
# Epoch 9/40
# 20/20 [==============================] - 0s 5ms/step - loss: 758.3536 - mse: 758.3536 - val_loss: 691.5176 - val_mse: 691.5176
# Epoch 10/40
# 20/20 [==============================] - 0s 5ms/step - loss: 741.2842 - mse: 741.2842 - val_loss: 675.5519 - val_mse: 675.5519
# Epoch 11/40
# 20/20 [==============================] - 0s 5ms/step - loss: 726.0955 - mse: 726.0955 - val_loss: 661.8829 - val_mse: 661.8829
# Epoch 12/40
# 20/20 [==============================] - 0s 5ms/step - loss: 712.3259 - mse: 712.3259 - val_loss: 648.9886 - val_mse: 648.9886
# Epoch 13/40
# 20/20 [==============================] - 0s 7ms/step - loss: 699.2933 - mse: 699.2933 - val_loss: 636.9303 - val_mse: 636.9303
# Epoch 14/40
# 20/20 [==============================] - 0s 6ms/step - loss: 687.0840 - mse: 687.0840 - val_loss: 625.5915 - val_mse: 625.5915
# Epoch 15/40
# 20/20 [==============================] - 0s 6ms/step - loss: 675.4240 - mse: 675.4240 - val_loss: 614.4327 - val_mse: 614.4327
# Epoch 16/40
# 20/20 [==============================] - 0s 5ms/step - loss: 663.9969 - mse: 663.9969 - val_loss: 603.8931 - val_mse: 603.8931
# Epoch 17/40
# 20/20 [==============================] - 0s 5ms/step - loss: 652.9750 - mse: 652.9750 - val_loss: 593.2484 - val_mse: 593.2484
# Epoch 18/40
# 20/20 [==============================] - 0s 5ms/step - loss: 642.0478 - mse: 642.0478 - val_loss: 583.0074 - val_mse: 583.0074
# Epoch 19/40
# 20/20 [==============================] - 0s 6ms/step - loss: 631.4048 - mse: 631.4048 - val_loss: 572.8954 - val_mse: 572.8954
# Epoch 20/40
# 20/20 [==============================] - 0s 5ms/step - loss: 620.8666 - mse: 620.8666 - val_loss: 562.9725 - val_mse: 562.9725
# Epoch 21/40
# 20/20 [==============================] - 0s 6ms/step - loss: 610.5393 - mse: 610.5393 - val_loss: 553.0816 - val_mse: 553.0816
# Epoch 22/40
# 20/20 [==============================] - 0s 5ms/step - loss: 600.2908 - mse: 600.2908 - val_loss: 543.4573 - val_mse: 543.4573
# Epoch 23/40
# 20/20 [==============================] - 0s 6ms/step - loss: 590.1221 - mse: 590.1221 - val_loss: 533.7429 - val_mse: 533.7429
# Epoch 24/40
# 20/20 [==============================] - 0s 5ms/step - loss: 580.0244 - mse: 580.0244 - val_loss: 524.2709 - val_mse: 524.2709
# Epoch 25/40
# 20/20 [==============================] - 0s 4ms/step - loss: 570.1843 - mse: 570.1843 - val_loss: 514.8821 - val_mse: 514.8821
# Epoch 26/40
# 20/20 [==============================] - 0s 6ms/step - loss: 560.4058 - mse: 560.4058 - val_loss: 505.6743 - val_mse: 505.6743
# Epoch 27/40
# 20/20 [==============================] - 0s 5ms/step - loss: 550.6429 - mse: 550.6429 - val_loss: 496.3874 - val_mse: 496.3874
# Epoch 28/40
# 20/20 [==============================] - 0s 5ms/step - loss: 541.0178 - mse: 541.0178 - val_loss: 487.3071 - val_mse: 487.3071
# Epoch 29/40
# 20/20 [==============================] - 0s 5ms/step - loss: 531.4981 - mse: 531.4981 - val_loss: 478.2862 - val_mse: 478.2862
# Epoch 30/40
# 20/20 [==============================] - 0s 5ms/step - loss: 522.0815 - mse: 522.0815 - val_loss: 469.4060 - val_mse: 469.4060
# Epoch 31/40
# 20/20 [==============================] - 0s 5ms/step - loss: 512.7582 - mse: 512.7582 - val_loss: 460.7260 - val_mse: 460.7260
# Epoch 32/40
# 20/20 [==============================] - 0s 6ms/step - loss: 503.5975 - mse: 503.5975 - val_loss: 451.9678 - val_mse: 451.9678
# Epoch 33/40
# 20/20 [==============================] - 0s 6ms/step - loss: 494.4458 - mse: 494.4458 - val_loss: 443.3778 - val_mse: 443.3778
# Epoch 34/40
# 20/20 [==============================] - 0s 6ms/step - loss: 485.4650 - mse: 485.4650 - val_loss: 434.8745 - val_mse: 434.8745
# Epoch 35/40
# 20/20 [==============================] - 0s 5ms/step - loss: 476.4903 - mse: 476.4903 - val_loss: 426.4947 - val_mse: 426.4947
# Epoch 36/40
# 20/20 [==============================] - 0s 5ms/step - loss: 467.6776 - mse: 467.6776 - val_loss: 418.0289 - val_mse: 418.0289
# Epoch 37/40
# 20/20 [==============================] - 0s 5ms/step - loss: 458.8659 - mse: 458.8659 - val_loss: 409.8244 - val_mse: 409.8244
# Epoch 38/40
# 20/20 [==============================] - 0s 5ms/step - loss: 450.2721 - mse: 450.2721 - val_loss: 401.8189 - val_mse: 401.8189
# Epoch 39/40
# 20/20 [==============================] - 0s 4ms/step - loss: 441.7328 - mse: 441.7328 - val_loss: 393.6825 - val_mse: 393.6825
# Epoch 40/40
# 20/20 [==============================] - 0s 5ms/step - loss: 433.2722 - mse: 433.2722 - val_loss: 385.8271 - val_mse: 385.8271
# 5/5 [==============================] - 0s 3ms/step

# %%
# loss 체크
import matplotlib.pyplot as plt
plt.figure(figsize=(10,7))
plt.plot(range(N_EPOCHS), history.history['loss'], label='train loss')
plt.plot(range(N_EPOCHS), history.history['val_loss'], label='test loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
model.evaluate(X_test, y_test)
# Out:
# 5/5 [==============================] - 0s 3ms/step - loss: 385.8271 - mse: 385.8271
# [385.8270568847656, 385.8270568847656]
